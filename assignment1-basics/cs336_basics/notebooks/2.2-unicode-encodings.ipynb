# %% [markdown]
# # 2.2 Unicode Encodings (3 pts)
#
# **Problem (unicode2):**
# - (a) Why prefer UTF-8 over UTF-16 or UTF-32?
# - (b) Why is `decode_utf8_bytes_to_str_wrong` incorrect? Provide a failing example.
# - (c) Give a two byte sequence that doesn't decode to any Unicode character.

# %%
# (a) UTF-8 vs UTF-16 vs UTF-32

# %%
# (b) decode_utf8_bytes_to_str_wrong failing example

# %%
# (c) Invalid two byte sequence

# %% [markdown]
# ## My Answers
#
# **(a):**
#
# **(b):**
#
# **(c):**
