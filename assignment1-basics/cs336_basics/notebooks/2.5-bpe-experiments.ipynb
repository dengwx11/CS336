# %% [markdown]
# # 2.5 Experimenting with BPE Training
#
# **Problem (train_bpe_tinystories):** (2 pts)
# - (a) Train with vocab_size=10,000. Time/memory? Longest token?
# - (b) Profile: what takes the most time?
#
# **Problem (train_bpe_expts_owt):** (2 pts)
# - (a) Train with vocab_size=32,000 on OWT. Longest token?
# - (b) Compare TinyStories vs OpenWebText tokenizers.

# %%
# TinyStories BPE training (vocab_size=10000)

# %%
# OpenWebText BPE training (vocab_size=32000)

# %%
# Profiling

# %% [markdown]
# ## My Answers
#
# **train_bpe_tinystories (a):**
#
# **train_bpe_tinystories (b):**
#
# **train_bpe_expts_owt (a):**
#
# **train_bpe_expts_owt (b):**
