# %% [markdown]
# # 2.6 BPE Encoding and Decoding (15 pts)
#
# **Problem (tokenizer):** Implement the tokenizer
# - `__init__`, `from_files`, `encode`, `encode_iterable`, `decode`
# - Test: `uv run pytest tests/test_tokenizer.py`

# %%
# Development and testing here

# %% [markdown]
# ## Design Decisions
# -
#
# ## Test Results
# ```
# # paste pytest output here
# ```
