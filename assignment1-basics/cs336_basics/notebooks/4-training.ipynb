# %% [markdown]
# # 4. Training a Transformer LM
#
# Cross-entropy, AdamW, LR scheduling, gradient clipping.
# Clean code goes in `cs336_basics/optimizer.py` and `cs336_basics/training.py`.

# %% [markdown]
# ## 4.1 Cross-Entropy Loss
# - `uv run pytest -k test_cross_entropy`

# %%
# Cross-entropy development

# %% [markdown]
# ## 4.2 Learning Rate Tuning (1 pt)
# Try lr=1e1, 1e2, 1e3 for 10 iterations on toy example.

# %%
# LR sweep experiment

# %% [markdown]
# ## 4.3 AdamW (2 pts)
# - `uv run pytest -k test_adamw`

# %%
# AdamW development

# %% [markdown]
# ## 4.3 AdamW Accounting (2 pts)
# - Peak memory, max batch_size, FLOPs per step, training time

# %%
# AdamW resource accounting calculations

# %% [markdown]
# ## 4.4 Cosine LR Schedule
# - `uv run pytest -k test_get_lr_cosine_schedule`

# %%
# LR schedule development

# %% [markdown]
# ## 4.5 Gradient Clipping (1 pt)
# - `uv run pytest -k test_gradient_clipping`

# %%
# Gradient clipping development

# %% [markdown]
# ## My Answers
#
# **learning_rate_tuning:**
#
# **adamwAccounting (a) peak memory:**
#
# **adamwAccounting (b) max batch_size:**
#
# **adamwAccounting (c) FLOPs per step:**
#
# **adamwAccounting (d) training time:**
