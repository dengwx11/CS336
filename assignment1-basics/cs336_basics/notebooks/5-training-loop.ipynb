# %% [markdown]
# # 5. Training Loop
#
# Data loading, checkpointing, and putting it all together.

# %% [markdown]
# ## 5.1 Data Loading (2 pts)
# - `uv run pytest -k test_get_batch`

# %%
# Data loader with np.memmap

# %% [markdown]
# ## 5.2 Checkpointing (1 pt)
# - `uv run pytest -k test_checkpointing`

# %%
# save_checkpoint / load_checkpoint

# %% [markdown]
# ## 5.3 Training Together (4 pts)
# Full training script with configurable hyperparameters.

# %%
# Training loop development and testing
