# %% [markdown]
# # 6. Generating Text (3 pts)
#
# **Problem (decoding):** Autoregressive decoding with temperature and top-p sampling.

# %%
# Decoding implementation and experiments

# %% [markdown]
# ## Generated Samples
# ```
# # paste generated text here
# ```
