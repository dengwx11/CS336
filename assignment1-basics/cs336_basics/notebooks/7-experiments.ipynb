# %% [markdown]
# # 7. Experiments
#
# TinyStories training, ablations, OWT, and leaderboard.
# **Requires GPU** for most experiments.

# %% [markdown]
# ## 7.1 Experiment Logging (3 pts)
# Setup W&B or custom logging.

# %%
# Logging setup

# %% [markdown]
# ## 7.2 TinyStories
#
# Base hyperparams: vocab=10K, ctx=256, d_model=512, d_ff=1344, 4 layers, 16 heads
#
# **learning_rate (3 pts):** LR sweep, target val loss <= 1.45
#
# **batch_size_experiment (1 pt):** Vary from 1 to GPU limit
#
# **generate (1 pt):** 256+ tokens, comment on fluency

# %%
# LR sweep experiments

# %%
# Batch size experiments

# %%
# Text generation

# %% [markdown]
# ## 7.3 Ablations (4 pts)
#
# - **layer_norm_ablation:** Remove RMSNorm
# - **pre_norm_ablation:** Post-norm vs pre-norm
# - **no_pos_emb:** Remove RoPE
# - **swiglu_ablation:** SwiGLU vs SiLU

# %%
# Ablation experiments (run on GPU)

# %% [markdown]
# ## 7.4 OpenWebText (2 pts)

# %%
# OWT training

# %% [markdown]
# ## 7.5 Leaderboard (6 pts)
# Minimize OWT validation loss within 1.5 H100 hours.
#
# ### Strategy
# -
#
# ### Results
# - Best val loss:
# - GPU hours:

# %%
# Leaderboard experiments

# %% [markdown]
# ## My Answers
#
# **learning_rate (a):**
#
# **learning_rate (b) edge of stability:**
#
# **batch_size_experiment:**
#
# **generate:**
#
# **layer_norm_ablation:**
#
# **pre_norm_ablation:**
#
# **no_pos_emb:**
#
# **swiglu_ablation:**
#
# **main_experiment:**
